# %% [markdown]
# # North Carolina Energy Analysis
# ## Project Overview

# %%
import pandas as pd
import requests as rq
import json
import datetime as dt
import prettytable
import sqlite3 as sql3
import plotly.express as px

# %% [markdown]
# ## Data Collection

# %%
prettytable.DEFAULT = 'DEFAULT'
conn = sql3.connect("North_Carolina_Energy_DB.db")
cursor = conn.cursor()
# %load_ext sql

# %%
eia_api_key = "kK9aQ8WWXRULzrrgc3JVhMFhDLoenNtyJ6jtTQWu"

# %%
today = dt.datetime.now()
from_date = today - dt.timedelta(days=30)

# %%
eia_daily_start = from_date.strftime("%Y-%m-%d")
eia_daily_end = dt.datetime.now().strftime("%Y-%m-%d")
eia_api_length = 30
eia_hourly_start = ""
eia_hourly_end = ""

# %% [markdown]
# ### Daily Demmand

# %%
eia_daily_url = f"https://api.eia.gov/v2/electricity/rto/daily-region-data/data/?frequency=daily&data[0]=value&facets[respondent][]=CAR&start={eia_daily_start}&end={eia_daily_end}&sort[0][column]=period&sort[0][direction]=desc&offset=0&length={eia_api_length}&api_key={eia_api_key}"

# %%
eia_daily_response = rq.get(eia_daily_url)
daily_data = eia_daily_response.json()
eia_daily_data = daily_data['response']['data']

# %% [markdown]
# ### Hourly Demand

# %%
eia_hourly_url = f"https://api.eia.gov/v2/electricity/rto/region-data/data/?frequency=hourly&data[0]=value&facets[type][]=D&facets[respondent][]=CAR&start={eia_daily_start}&end={eia_daily_end}&sort[0][column]=period&sort[0][direction]=desc&offset=0&length={eia_api_length}&api_key={eia_api_key}"

# %%
eia_hourly_response = rq.get(eia_hourly_url)
hourly_data = eia_hourly_response.json()
eia_hourly_data = hourly_data['response']['data']
eia_hourly_data
# Out:
# [{'period': '2026-06-25T13',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '24430',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T12',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '23112',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T11',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '21627',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T10',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '20600',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T09',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '20084',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T08',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '20126',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T07',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '20744',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T06',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '21710',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T05',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '23194',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T04',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '25245',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T03',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '27832',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T02',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '30365',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T01',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '31872',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-25T00',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '33557',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T23',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '34813',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T22',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '35140',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T21',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '34788',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T20',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '34121',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T19',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '33351',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T18',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '32345',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T17',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '30924',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T16',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '29491',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T15',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '27850',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T14',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '26241',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T13',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '24710',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T12',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '23186',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T11',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '21840',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T10',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '21031',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T09',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '20513',
#   'value-units': 'megawatthours'},
#  {'period': '2026-06-24T08',
#   'respondent': 'CAR',
#   'respondent-name': 'Carolinas',
#   'type': 'D',
#   'type-name': 'Demand',
#   'value': '20748',
#   'value-units': 'megawatthours'}]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Daily Demand

# %%
d_rows = []
for item in eia_daily_data:
    d_rows.append({
        "Date": pd.to_datetime(item["period"]),
        "Demand (MWh)": item["value"]
    })
eia_daily_df = pd.DataFrame(d_rows)
eia_daily_df.dropna(inplace=True)

# %% [markdown]
# ### Hourly Demand

# %%
h_rows = []
for item in eia_hourly_data:
    h_rows.append({
        "Datetime": pd.to_datetime(item["period"]),
        "Date": pd.to_datetime(item["period"]).date(),
        "Hour": pd.to_datetime(item["period"]).hour,
        "Demand (MWh)": item["value"]
    })
eia_hourly_df = pd.DataFrame(h_rows)
eia_hourly_df.dropna(inplace=True)

# %% [markdown]
# ## Database Creation
# ### Daily Demand

# %%
eia_daily_df.to_sql("NC_DAILY_ELECTRICITY_DEMAND", conn, if_exists='replace', index=False, method='multi');
# %sql sqlite:///North_Carolina_Energy_DB.db

# %% [markdown]
# ### Hourly Demand

# %%
eia_daily_df.to_sql("NC_HOURLY_ELECTRICITY_DEMAND", conn, if_exists='replace', index=False, method='multi');
# %sql sqlite:///North_Carolina_Energy_DB.db

# %% [markdown]
# ## SQL Analysis

# %%
# %sql select * from NC_DAILY_ELECTRICITY_DEMAND;
# Out:
#  * sqlite:///North_Carolina_Energy_DB.db
# Done.
# [('2026-06-25 00:00:00', '618315'),
#  ('2026-06-24 00:00:00', '665611'),
#  ('2026-06-24 00:00:00', '667257'),
#  ('2026-06-24 00:00:00', '668302'),
#  ('2026-06-24 00:00:00', '666266'),
#  ('2026-06-24 00:00:00', '665611'),
#  ('2026-06-24 00:00:00', '597303'),
#  ('2026-06-24 00:00:00', '598691'),
#  ('2026-06-24 00:00:00', '688512'),
#  ('2026-06-24 00:00:00', '597931'),
#  ('2026-06-24 00:00:00', '597303'),
#  ('2026-06-24 00:00:00', '598706'),
#  ('2026-06-24 00:00:00', '598706'),
#  ('2026-06-24 00:00:00', '672572'),
#  ('2026-06-24 00:00:00', '598706'),
#  ('2026-06-24 00:00:00', '598706'),
#  ('2026-06-24 00:00:00', '16118'),
#  ('2026-06-23 00:00:00', '742457'),
#  ('2026-06-23 00:00:00', '751096'),
#  ('2026-06-23 00:00:00', '755595'),
#  ('2026-06-23 00:00:00', '746771'),
#  ('2026-06-23 00:00:00', '742457'),
#  ('2026-06-23 00:00:00', '649976'),
#  ('2026-06-23 00:00:00', '655049'),
#  ('2026-06-23 00:00:00', '657786'),
#  ('2026-06-23 00:00:00', '652447'),
#  ('2026-06-23 00:00:00', '649976'),
#  ('2026-06-23 00:00:00', '736053'),
#  ('2026-06-23 00:00:00', '743930'),
#  ('2026-06-23 00:00:00', '747978')]
